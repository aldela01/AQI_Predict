# %%
import pandas as pd

# %%
# Show unlimited number of columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
features_df = pd.read_parquet('../../data/processed/features_h24_v1.parquet')  # or the correct path

# %%
features_df.iloc[24:30, :]
# Out:
#    station_id           timestamp  split  hour  dow  month  is_weekend  \
# 24   BAR-TORR 2019-01-02 01:00:00  train     1    2      1           0
# 25   BAR-TORR 2019-01-02 02:00:00  train     2    2      1           0
# 26   BAR-TORR 2019-01-02 03:00:00  train     3    2      1           0
# 27   BAR-TORR 2019-01-02 04:00:00  train     4    2      1           0
# 28   BAR-TORR 2019-01-02 05:00:00  train     5    2      1           0
# 29   BAR-TORR 2019-01-02 06:00:00  train     6    2      1           0
#
#         pm25  pm10  o3  tair_10m  rh_10m  press  r_global  wind_speed  \
# 24   9.38444   NaN NaN       NaN     NaN    NaN       NaN         NaN
# 25   7.02637   NaN NaN       NaN     NaN    NaN       NaN         NaN
# 26  10.51870   NaN NaN       NaN     NaN    NaN       NaN         NaN
# 27   7.00512   NaN NaN       NaN     NaN    NaN       NaN         NaN
# 28  10.48380   NaN NaN       NaN     NaN    NaN       NaN         NaN
# ...

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1739772 entries, 0 to 1739771
# Data columns (total 65 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   station_id           object
#  1   timestamp            datetime64[ns]
#  2   split                object
#  3   hour                 int32
#  4   dow                  int32
#  5   month                int32
#  6   is_weekend           int64
#  7   pm25                 float64
#  8   pm10                 float64
#  9   o3                   float64
#  10  tair_10m             float64
#  11  rh_10m               float64
#  12  press                float64
#  13  r_global             float64
#  14  wind_speed           float64
#  15  wind_dir             float64
#  16  y_h01                float64
#  17  y_h02                float64
#  18  y_h03                float64
#  19  y_h04                float64
#  20  y_h05                float64
#  21  y_h06                float64
# ...

# %%
dups = features_df.duplicated(["station_id", "timestamp"]).sum()

# %%
dups
# Out:
# np.int64(869886)

# %%
print(features_df.groupby(["station_id","timestamp"]).size().value_counts().head(10))
# Out:
# 2    869886
# Name: count, dtype: int64

# %%
features_df.shape
# Out:
# (1739772, 65)
